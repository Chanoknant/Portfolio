# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('annotation_meta_data_processed.csv')

# %%
# create colume CVAT page 
L = [] 
for i in range(len(df)) :
    L.append(i)
df['CVAT page'] = L

# %%
df.head()
# Out:
#       Image Index  AccessionNumber  AcquisitionDate  PatientID  \
# 0  23884422-0.png         23884422         20150813   38032169
# 1  23965545-0.png         23965545         20151020   38032169
# 2  24094327-0.png         24094327         20160209   38032169
# 3  24333661-0.png         24333661         20160829   38032169
# 4  24784721-0.png         24784721         20170831   38032169
#
#    Tuberculosis Balanced Score  Tuberculosis Found        Case Type  \
# 0                     0.862615                 1.0  CT Confirm Case
# 1                     0.137030                 0.0   Follow Up Case
# 2                     0.357307                 0.0   Follow Up Case
# 3                     0.132823                 0.0   Follow Up Case
# 4                     0.238729                 0.0   Follow Up Case
#
#   Diagnosed date  CVAT page
# 0       20150813          0
# 1       20150813          1
# 2       20150813          2
# 3       20150813          3
# 4       20150813          4

# %%
len(df['PatientID'].unique())
# Out:
# 73

# %%
df['Case Type'].unique()
# Out:
# array(['CT Confirm Case', 'Follow Up Case', 'Early Case',
#        'Not in 73 patient'], dtype=object)

# %%
df[df['Case Type']== 'CT Confirm Case']
# Out:
#         Image Index  AccessionNumber  AcquisitionDate  PatientID  \
# 0    23884422-0.png         23884422         20150813   38032169
# 7    25369875-0.png         25369875         20181130   38177734
# 9    23650713-0.png         23650713         20150127   39149900
# 15   24756299-0.png         24756299         20170809   39166583
# 18   23571095-0.png         23571095         20141117   40035160
# ..              ...              ...              ...        ...
# 375  24387929-0.png         24387929         20161012   53537076
# 381  24770557-0.png         24770557         20170821   53658976
# 388  25176538-0.png         25176538         20180704   53661586
# 390  25377641-0.png         25377641         20181207   53777322
# 391  25154490-0.png         25154490         20180618   53805049
#
#      Tuberculosis Balanced Score  Tuberculosis Found        Case Type  \
# 0                       0.862615                 1.0  CT Confirm Case
# ...

# %%
L = []
for i in df['Diagnosed date']: 
    L.append(i.isdigit())
L
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
for index,row in df[['Diagnosed date']].iterrows() :
    if row[0].isdigit() == False :
        print(index , row[0])
# Out:
# 374 None

# %%
df['Diagnosed date'].loc[374] = np.nan
# Out:
# /var/folders/m4/mqwz4y154cd5h9gpw9pwh86m0000gn/T/ipykernel_1625/1212810259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Diagnosed date'].loc[374] = np.nan

# %%
df[['Diagnosed date','AcquisitionDate']]
# Out:
#     Diagnosed date  AcquisitionDate
# 0         20150813         20150813
# 1         20150813         20151020
# 2         20150813         20160209
# 3         20150813         20160829
# 4         20150813         20170831
# ..             ...              ...
# 389       20181207         20180402
# 390       20181207         20181207
# 391       20180618         20180618
# 392       20180618         20180806
# 393       20180618         20181001
#
# [394 rows x 2 columns]

# %%
df['AcquisitionDate'] = df['AcquisitionDate'].astype('int')

# %%
df['AcquisitionDate']
# Out:
# 0      20150813
# 1      20151020
# 2      20160209
# 3      20160829
# 4      20170831
#          ...
# 389    20180402
# 390    20181207
# 391    20180618
# 392    20180806
# 393    20181001
# Name: AcquisitionDate, Length: 394, dtype: int64

# %%
df['AcquisitionDate'] = pd.to_datetime(df['AcquisitionDate'],format = '%Y%m%d')

# %%
df['AcquisitionDate']
# Out:
# 0     2015-08-13
# 1     2015-10-20
# 2     2016-02-09
# 3     2016-08-29
# 4     2017-08-31
#          ...
# 389   2018-04-02
# 390   2018-12-07
# 391   2018-06-18
# 392   2018-08-06
# 393   2018-10-01
# Name: AcquisitionDate, Length: 394, dtype: datetime64[ns]

# %%
df['Diagnosed date'] = pd.to_datetime(df['Diagnosed date'])

# %%
df['Diagnosed date']
# Out:
# 0     2015-08-13
# 1     2015-08-13
# 2     2015-08-13
# 3     2015-08-13
# 4     2015-08-13
#          ...
# 389   2018-12-07
# 390   2018-12-07
# 391   2018-06-18
# 392   2018-06-18
# 393   2018-06-18
# Name: Diagnosed date, Length: 394, dtype: datetime64[ns]

# %%
df['days from CT scan'] = (df['AcquisitionDate'] - df['Diagnosed date'])

# %%
df['days from CT scan']
# Out:
# 0        0 days
# 1       68 days
# 2      180 days
# 3      382 days
# 4      749 days
#          ...
# 389   -249 days
# 390      0 days
# 391      0 days
# 392     49 days
# 393    105 days
# Name: days from CT scan, Length: 394, dtype: timedelta64[ns]

# %%
df['days from CT scan'] = df['days from CT scan'].astype('str')
df['days from CT scan']
# Out:
# 0         0 days
# 1        68 days
# 2       180 days
# 3       382 days
# 4       749 days
#          ...
# 389    -249 days
# 390       0 days
# 391       0 days
# 392      49 days
# 393     105 days
# Name: days from CT scan, Length: 394, dtype: object

# %%
df['days from CT scan'] = df['days from CT scan'].str.strip('days')
df['days from CT scan'].loc[374] = 0
# Out:
# /var/folders/m4/mqwz4y154cd5h9gpw9pwh86m0000gn/T/ipykernel_1625/2837787436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days from CT scan'].loc[374] = 0

# %%
df['days from CT scan'] = df['days from CT scan'].astype('int')

# %%
df['days from CT scan'].loc[374] = 9999999999999
# Out:
# /var/folders/m4/mqwz4y154cd5h9gpw9pwh86m0000gn/T/ipykernel_1625/107516549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days from CT scan'].loc[374] = 9999999999999

# %%
df = df.drop(index = 374)

# %%
for i in df['PatientID'].unique() :
    print(df.set_index('PatientID').loc[i]['days from CT scan'])
# Out:
# PatientID
# 38032169       0
# 38032169      68
# 38032169     180
# 38032169     382
# 38032169     749
# 38032169    1099
# 38032169    1812
# Name: days from CT scan, dtype: int64
# PatientID
# 38177734     0
# 38177734    67
# Name: days from CT scan, dtype: int64
# PatientID
# 39149900       0
# 39149900      70
# 39149900     188
# 39149900     433
# 39149900     701
# 39149900    1102
# Name: days from CT scan, dtype: int64
# PatientID
# 39166583      0
# 39166583     90
# 39166583    202
# Name: days from CT scan, dtype: int64
# PatientID
# 40035160     0
# 40035160    77
# Name: days from CT scan, dtype: int64
# PatientID
# 40092568   -1195
# 40092568   -1161
# 40092568    -720
# 40092568    -353
# 40092568       0
# 40092568      67
# 40092568     186
# 40092568     368
# 40092568     736
# 40092568    1091
# Name: days from CT scan, dtype: int64
# PatientID
# 40103435       0
# 40103435      31
# 40103435      69
# 40103435     186
# 40103435     360
# 40103435    1092
# ...

# %%
# Cases that have CXR before CT confirm and be found by AI 
CC = df[(df['Case Type']=='CT Confirm Case')]
CC.head()
# Out:
#        Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 0   23884422-0.png         23884422      2015-08-13   38032169
# 7   25369875-0.png         25369875      2018-11-30   38177734
# 9   23650713-0.png         23650713      2015-01-27   39149900
# 15  24756299-0.png         24756299      2017-08-09   39166583
# 18  23571095-0.png         23571095      2014-11-17   40035160
#
#     Tuberculosis Balanced Score  Tuberculosis Found        Case Type  \
# 0                      0.862615                 1.0  CT Confirm Case
# 7                      0.906810                 1.0  CT Confirm Case
# 9                      0.907183                 1.0  CT Confirm Case
# 15                     0.876467                 1.0  CT Confirm Case
# 18                     0.905993                 1.0  CT Confirm Case
#
#    Diagnosed date  CVAT page  days from CT scan
# 0      2015-08-13          0                  0
# 7      2018-11-30          7                  0
# ...

# %%
# not in 73 paatient 53519213
df[df['PatientID']==53519213]
# Out:
# Empty DataFrame
# Columns: [Image Index, AccessionNumber, AcquisitionDate, PatientID, Tuberculosis Balanced Score, Tuberculosis Found, Case Type, Diagnosed date, CVAT page, days from CT scan]
# Index: []

# %%
CC['days from CT scan']
# Out:
# 0      0
# 7      0
# 9      0
# 15     0
# 18     0
#       ..
# 375    0
# 381    0
# 388    0
# 390    0
# 391    0
# Name: days from CT scan, Length: 66, dtype: int64

# %%
df[df['days from CT scan']<= -30]
# Out:
#         Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 20   23133117-0.png         23133117      2013-10-26   40092568
# 21   23171306-0.png         23171306      2013-11-29   40092568
# 22   23672492-0.png         23672492      2015-02-13   40092568
# 23   24098346-0.png         24098346      2016-02-15   40092568
# 45   22249059-0.png         22249059      2011-07-13   41096287
# 46   22611907-0.png         22611907      2012-07-09   41096287
# 47   23011758-0.png         23011758      2013-07-10   41096287
# 48   23508125-0.png         23508125      2014-09-24   41096287
# 49   23711919-0.png         23711919      2015-03-18   41096287
# 50   23961352-0.png         23961352      2015-10-16   41096287
# 63   23551537-0.png         23551537      2014-10-31   41129728
# 82   24636387-0.png         24636387      2017-05-05   43091080
# 88   23967014-0.png         23967014      2015-10-21   43112431
# 104  25315557-0.png         25315557      2018-10-19   47117367
# ...

# %%
len(df[df['days from CT scan']<= -30])
# Out:
# 51

# %%
# Early cases - cases that underwent CT scan > 30 days before 
EC = df[df['days from CT scan']<= -30]

# %%
EC[EC['Tuberculosis Found']==0.0]
# Out:
#         Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 22   23672492-0.png         23672492      2015-02-13   40092568
# 23   24098346-0.png         24098346      2016-02-15   40092568
# 63   23551537-0.png         23551537      2014-10-31   41129728
# 88   23967014-0.png         23967014      2015-10-21   43112431
# 144  22762194-0.png         22762194      2012-11-21   49109348
# 173  23138873-0.png         23138873      2013-10-31   50150289
# 174  23675437-0.png         23675437      2015-02-16   50150289
# 322  23245532-0.png         23245532      2014-02-10   53077391
# 338  24162300-0.png         24162300      2016-04-05   53303708
# 379  24645335-0.png         24645335      2017-05-15   53658976
#
#      Tuberculosis Balanced Score  Tuberculosis Found   Case Type  \
# 22                      0.032476                 0.0  Early Case
# 23                      0.331649                 0.0  Early Case
# ...

# %%
len(EC[EC['Tuberculosis Found']==1.0]['PatientID'].unique())
# Out:
# 19

# %%
# CXR that have definite diagnosis (DD) (14day before and after diagnosis of TB)
DD = df[(df['days from CT scan']>=-14)&(df['days from CT scan']<=14)]
len(DD)
# Out:
# 70

# %%
len(DD[DD['Tuberculosis Found']==0.0])
# Out:
# 8

# %%
len(DD[DD['Tuberculosis Found']==1.0])
# Out:
# 62

# %%
len(df[(df['Tuberculosis Found']==0.0)&(df['Case Type']=='CT Confirm Case')])
# Out:
# 8

# %%
# tuberculosis cases in each years
print('2019',len(DD[DD['Diagnosed date'].dt.year == 2019]))
print('2018',len(DD[DD['Diagnosed date'].dt.year == 2018]))
print('2017',len(DD[DD['Diagnosed date'].dt.year == 2017]))
print('2016',len(DD[DD['Diagnosed date'].dt.year == 2016]))
print('2015', len(DD[DD['Diagnosed date'].dt.year == 2015]))
print('2014',len(DD[DD['Diagnosed date'].dt.year == 2014]))
# Out:
# 2019 3
# 2018 14
# 2017 12
# 2016 16
# 2015 19
# 2014 6

# %%
19+16+12+14
# Out:
# 61

# %%
# months that each cases were diagnosed in 2015 
ax = DD[DD['Diagnosed date'].dt.year == 2015]['Diagnosed date'].dt.month.value_counts().sort_index().plot(kind = 'bar')
ax.set_xlabel("Month")
ax.set_ylabel("Tuberculosis cases")
# Out:
# Text(0, 0.5, 'Tuberculosis cases')

# %%
DD[DD['Diagnosed date'].dt.year == 2015]
# Out:
#         Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 0    23884422-0.png         23884422      2015-08-13   38032169
# 9    23650713-0.png         23650713      2015-01-27   39149900
# 51   24045496-0.png         24045496      2015-12-29   41096287
# 64   23975413-0.png         23975413      2015-10-29   41129728
# 65   23992111-0.png         23992111      2015-11-12   41129728
# 98   23749900-0.png         23749900      2015-04-22   44144439
# 106  23866649-0.png         23866649      2015-07-28   47200794
# 115  23629088-0.png         23629088      2015-01-09   48187144
# 146  23723325-0.png         23723325      2015-03-27   49109348
# 185  23996314-0.png         23996314      2015-11-16   50327273
# 187  23806472-0.png         23806472      2015-06-09   51181927
# 230  23894462-0.png         23894462      2015-08-21   52561441
# 286  23805107-0.png         23805107      2015-06-08   52836155
# 298  23975466-0.png         23975466      2015-10-29   52879457
# ...

# %%
DD[DD['Diagnosed date'].dt.year == 2018]['Diagnosed date'].dt.month.value_counts().index
# Out:
# Int64Index([1, 7, 11, 3, 10, 4, 8, 12, 6], dtype='int64')

# %%
DD[(DD['Diagnosed date'].dt.year == 2015)&(DD['Diagnosed date'].dt.month >= 6 )]
# Out:
#         Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 0    23884422-0.png         23884422      2015-08-13   38032169
# 51   24045496-0.png         24045496      2015-12-29   41096287
# 64   23975413-0.png         23975413      2015-10-29   41129728
# 65   23992111-0.png         23992111      2015-11-12   41129728
# 106  23866649-0.png         23866649      2015-07-28   47200794
# 185  23996314-0.png         23996314      2015-11-16   50327273
# 187  23806472-0.png         23806472      2015-06-09   51181927
# 230  23894462-0.png         23894462      2015-08-21   52561441
# 286  23805107-0.png         23805107      2015-06-08   52836155
# 298  23975466-0.png         23975466      2015-10-29   52879457
# 352  23860054-0.png         23860054      2015-07-22   53373740
# 358  23973995-0.png         23973995      2015-10-28   53419226
# 369  24026458-0.png         24026458      2015-12-14   53456119
#
# ...

# %%
DD[(DD['Diagnosed date'].dt.year == 2018)&(DD['Diagnosed date'].dt.month >= 6 )]
# Out:
#         Image Index  AccessionNumber AcquisitionDate  PatientID  \
# 7    25369875-0.png         25369875      2018-11-30   38177734
# 73   25306407-0.png         25306407      2018-10-11   43065503
# 96   25198678-0.png         25198678      2018-07-20   43144124
# 171  25228890-0.png         25228890      2018-08-15   49207075
# 186  25369973-0.png         25369973      2018-11-30   51131930
# 301  25179463-0.png         25179463      2018-07-06   52923887
# 388  25176538-0.png         25176538      2018-07-04   53661586
# 390  25377641-0.png         25377641      2018-12-07   53777322
# 391  25154490-0.png         25154490      2018-06-18   53805049
#
#      Tuberculosis Balanced Score  Tuberculosis Found        Case Type  \
# 7                       0.906810                 1.0  CT Confirm Case
# 73                      0.918058                 1.0  CT Confirm Case
# 96                      0.663474                 1.0  CT Confirm Case
# ...

# %%
len(df[df['Case Type']=='CT Confirm Case'])
# Out:
# 66

# %%
len(EC)
# Out:
# 51

# %%
len(DD)
# Out:
# 70

# %%
393-55-66
# Out:
# 272

# %%
df['Case Type'].unique()
# Out:
# array(['CT Confirm Case', 'Follow Up Case', 'Early Case'], dtype=object)
